# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Encoded_House.csv")

target_column = 'log_price'
x = df.drop(['log_price','price'],axis=1)
y = df[target_column]

scaler = StandardScaler()
x_scaled = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# Fit linear model
x_const = sm.add_constant(x_scaled)
model = sm.OLS(y, x_const).fit()
residuals = model.resid

# %% [markdown]
# ### 1. Linearity Check

# %%
fitted_vals = model.fittedvalues
residuals = model.resid

sns.residplot(x=fitted_vals, y=residuals, line_kws={'color': 'red'})
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Fitted (Linearity)')
plt.show()

# %% [markdown]
# ### 2.Multicollinearity

# %%
# VIF calculation
vif = pd.DataFrame()
vif["Feature"] = x.columns
vif["VIF"] = [variance_inflation_factor(x_scaled.values, i) for i in range(x_scaled.shape[1])]
print(vif)
# Out:
#                              Feature        VIF
# 0                               area   1.042347
# 1                            bedRoom   7.889810
# 2                           bathroom   8.995614
# 3                            balcony   1.940786
# 4                           floorNum   1.201401
# 5                             others   1.271263
# 6                         pooja room   1.889087
# 7                       servant room   2.079262
# 8                         store room   1.561607
# 9                         study room   1.819676
# 10                       Environment  27.939590
# 11                         Lifestyle  44.469253
# 12                      Connectivity  31.950594
# 13                            Safety  35.887706
# 14                          Wardrobe   3.739408
# 15                               Fan   4.113112
# 16                       Exhaust Fan   2.759238
# 17                            Geyser   4.066087
# 18                             Light   2.191240
# 19                   Modular Kitchen   2.471983
# 20                                AC   2.296098
# 21                           Chimney   2.065850
# 22                               Bed   1.971596
# 23                          Curtains   1.507579
# 24                      Dining Table   2.346317
# 25                         Microwave   1.784762
# 26                            Fridge   3.020141
# 27                              Sofa   2.923232
# 28                             Stove   1.987612
# 29                                TV   1.975079
# 30                   Washing Machine   3.174859
# 31                    Water Purifier   1.981280
# 32                       facing_East   1.578467
# 33                      facing_North   1.438707
# 34                 facing_North-East   1.545382
# 35                 facing_North-West   1.220671
# 36                      facing_South   1.168999
# 37                 facing_South-East   1.169158
# 38                 facing_South-West   1.159485
# 39                       facing_West   1.338169
# 40     agePossession_0 to 1 Year Old   2.041398
# 41     agePossession_1 to 5 Year Old   2.781716
# 42        agePossession_10+ Year Old   2.426692
# 43    agePossession_5 to 10 Year Old   2.813989
# 44             agePossession_By 2024   1.014430
# 45             agePossession_By 2027   1.011681
# 46            agePossession_Dec 2023   1.039115
# 47            agePossession_Dec 2024   1.057976
# 48            agePossession_Jan 2024   1.026085
# 49            agePossession_Jun 2024   1.028427
# 50            agePossession_Oct 2023   1.050760
# 51            agePossession_Oct 2024   1.128405
# 52  agePossession_Under Construction   1.046716
# 53     agePossession_Within 3 months   1.061869
# 54     agePossession_Within 6 months   1.159865

# %% [markdown]
# ### 3.Normality
# #### Histogram + QQ plot + Shapiro-Wilk Test

# %%
shapiro_stat, shapiro_p = stats.shapiro(residuals)
print(f"Shapiro-Wilk Test: Stat={shapiro_stat:.3f}, p-value={shapiro_p:.3f}")

sns.histplot(residuals, kde=True)
plt.title("Histogram of Residuals")
plt.show()

sm.qqplot(residuals, line='45', fit=True)
plt.title("Q-Q Plot of Residuals")
plt.show()
# Out:
# Shapiro-Wilk Test: Stat=0.987, p-value=0.000

# %% [markdown]
# ### 4. Outliers

# %%
influence = model.get_influence()
standardized_residuals = influence.resid_studentized_internal

outlier_indices = np.where(np.abs(standardized_residuals) > 3)[0]
print(f"Potential outlier indices: {outlier_indices}")

# Plot standardized residuals
plt.figure(figsize=(10, 5))
plt.stem(standardized_residuals)
plt.axhline(y=3, color='r', linestyle='--')
plt.axhline(y=-3, color='r', linestyle='--')
plt.title("Standardized Residuals (Outlier Detection)")
plt.xlabel("Observation Index")
plt.ylabel("Standardized Residual")
plt.show()
# Out:
# f:\Regression_project\venv_reg\Lib\site-packages\statsmodels\stats\outliers_influence.py:847: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)
# Potential outlier indices: [207 228 236 506 623]

# %% [markdown]
# ### 5.Homoscedasticity (Equal variance of residuals)

# %%
fitted_vals = model.fittedvalues
residuals = model.resid

plt.figure(figsize=(8, 5))
plt.scatter(fitted_vals, residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Homoscedasticity Check (Residuals vs Fitted)")
plt.show()
